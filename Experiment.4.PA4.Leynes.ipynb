# %% [markdown]
# # Programming Experiment 4️⃣ | **ECE Board Exam Problem**
# ### `📊 Data Wrangling and Data Visualization`

# %%
#Import the required related library
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## ECE Board Exam Data 💽

# %%
#Load the board2.xlsx, csv file into a data frame using pandas.
enggeceexamds = pd.read_excel('board2.xlsx')
enggeceexamds
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %% [markdown]
# ## Problem 1️⃣ Data Frames 🐼

# %% [markdown]
# #### **1️a.** Create the following data frames based on the format provided:
# #### Filename: `Instru [“Name”, “GEAS”, “Electronics >70”]; where track is constant as Instrumentation and hometown Luzon`

# %%
#Data filtering using pandas with conditions
Instru = enggeceexamds.loc[(enggeceexamds ['Track'] == 'Instrumentation') & 
                           (enggeceexamds ['Hometown'] == 'Luzon') &
                           (enggeceexamds ['Electronics'] > 70), ['Name', 'GEAS', 'Electronics']]
Instru
# Out:
#    Name  GEAS  Electronics
# 0    S1    75           89
# 7    S8    64           81
# 29  S30    57           81

# %% [markdown]
# #### **1️b.** Create the following data frames based on the format provided:
# #### Filename: `Mindy = [ “Name”, “Track”, “Electronics”, “Average >=55”]; where hometown is constant as Mindanao and gender Female`

# %%
#Calculates the average for all subjects
enggeceexamds['Average'] = (enggeceexamds['Math'] + enggeceexamds['Electronics'] + 
                            enggeceexamds['GEAS'] + enggeceexamds['Communication']) / 4

#Data filtering using pandas with conditions
Mindy = enggeceexamds.loc[(enggeceexamds['Hometown']=='Mindanao') & 
                          (enggeceexamds['Gender']=='Female') & 
                          (enggeceexamds['Average']>=55), ('Name','Track','Electronics','Average')]
Mindy
# Out:
#    Name             Track  Electronics  Average
# 1    S2     Communication           75    67.25
# 2    S3   Instrumentation           74    72.75
# 14  S15  Microelectronics           41    59.00
# 16  S17  Microelectronics           79    70.50
# 19  S20     Communication           60    66.50

# %% [markdown]
# ## Problem 2️⃣ Visualization 📊

# %% [markdown]
# #### Create a visualization that shows how the different features contributes to average grade.
# #### `Does chosen track in college, gender, or hometown contributes to a higher average score?`

# %%
#Transform the data to a graph (Track = Blue, Gender = Orange, Hometown = Green)
plt.figure(figsize=(15, 5))
plt.bar(enggeceexamds['Track'], enggeceexamds['Average'])
plt.bar(enggeceexamds['Gender'], enggeceexamds['Average'])
plt.bar(enggeceexamds['Hometown'], enggeceexamds['Average'])

#Add titles and labels
plt.title('Average Grades by Track, Gender, and Hometown')
plt.xlabel('Categories')
plt.ylabel('Average Grade')
# Out:
# Text(0, 0.5, 'Average Grade')

# %% [markdown]
# #### End of Problem | Experiment 4
